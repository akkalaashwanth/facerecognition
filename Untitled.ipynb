# %%
# !pip install tensorflow opencv-python matplotlib

# %%
import cv2
import os
import random
import numpy as np
from matplotlib import pyplot as plt

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Conv2D, Dense, MaxPooling2D , Input ,Flatten
import tensorflow as tf

# %%
gpus=tf.config.experimental.list_physical_devices('GPU')
len(gpus)
# Out:
# 0

# %%
POS_PATH=os.path.join('data','positive')
NEG_PATH=os.path.join('data','negative')
ANC_PATH=os.path.join('data','anchor')

# %%
#os.makedirs(POS_PATH)
#os.makedirs(ANC_PATH)
#os.makedirs(NEG_PATH)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15540/2661008598.py in <module>
# ----> 1 os.makedirs(POS_PATH)
#       2 os.makedirs(ANC_PATH)
#       3 os.makedirs(NEG_PATH)
#
# ~\anaconda3\lib\os.py in makedirs(name, mode, exist_ok)
#     223             return
#     224     try:
# --> 225         mkdir(name, mode)
#     226     except OSError:
#     227         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'data\\positive'

# %%
for directory in os.listdir('lfw_funneled'):
    for file in os.listdir(os.path.join('lfw_funneled',directory)):
        xpath=os.path.join('lfw_funneled',directory,file)
        pathnew=os.path.join(NEG_PATH,file)
        os.replace(xpath,pathnew)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15540/2603308764.py in <module>
# ----> 1 for directory in os.listdir('lfw_funneled'):
#       2     for file in os.listdir(os.path.join('lfw_funneled',directory)):
#       3         xpath=os.path.join('lfw_funneled',directory,file)
#       4         pathnew=os.path.join(NEG_PATH,file)
#       5         os.replace(xpath,pathnew)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'lfw_funneled'

# %%
import uuid

# %%
cap=cv2.VideoCapture(0)
while cap.isOpened():
    ret,frame=cap.read()
    frame=frame[300:300+250,300:300+250, :]
    cv2.imshow('Image Collection',frame)
    if cv2.waitKey(1) & 0XFF==ord('a'):
        imgname=os.path.join(ANC_PATH,'{}.jpg'.format(uuid.uuid1()))
        cv2.imwrite(imgname,frame)
    if cv2.waitKey(1) & 0XFF==ord('p'):
        imgname=os.path.join(POS_PATH,'{}.jpg'.format(uuid.uuid1()))
        cv2.imwrite(imgname,frame)
        
    if cv2.waitKey(1) & 0XFF==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
anchor=tf.data.Dataset.list_files(ANC_PATH+'\*jpg').take(200)
positive=tf.data.Dataset.list_files(POS_PATH+'\*jpg').take(200)
negative=tf.data.Dataset.list_files(NEG_PATH+'\*jpg').take(200)

# %%
dir_test=anchor.as_numpy_iterator()
dir_test.next()
# Out:
# b'data\\anchor\\b73a41e9-765d-11ef-a70a-0045e2a52e34.jpg'

# %%
def preprocess(file_path):
    b_img = tf.io.read_file(file_path)  # Read image file
    img = tf.io.decode_jpeg(b_img)      # Decode jpeg image
    img = tf.image.resize(img, (100, 100))  # Resize the image to 100x100
    img = img / 255.0                   # Normalize to [0, 1]
    return img

# %%
positives=tf.data.Dataset.zip((anchor,positive,tf.data.Dataset.from_tensor_slices(tf.ones(len(anchor)))))
negatives=tf.data.Dataset.zip((anchor,negative,tf.data.Dataset.from_tensor_slices(tf.zeros(len(anchor)))))
data=positives.concatenate(negatives)

# %%
samples=data.as_numpy_iterator()
samples.next()
# Out:
# (b'data\\anchor\\b41d9b09-765d-11ef-87cf-0045e2a52e34.jpg',
#  b'data\\positive\\e90dc898-765d-11ef-90ab-0045e2a52e34.jpg',
#  1.0)

# %%
def twin(input_img,validation_img,label):
    return(preprocess(input_img),preprocess(validation_img),label)

# %%
data=data.map(twin)
data=data.cache()
data=data.shuffle(buffer_size=1024)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15540/540089800.py in <module>
# ----> 1 data=data.map(twin)
#       2 data=data.cache()
#       3 data=data.shuffle(buffer_size=1024)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic, name)
#    2278     # pylint: disable=g-import-not-at-top,protected-access
#    2279     from tensorflow.python.data.ops import map_op
# -> 2280     return map_op._map_v2(
#    2281         self,
#    2282         map_func,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\map_op.py in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, name)
#      35       warnings.warn("The `deterministic` argument has no effect unless the "
#      36                     "`num_parallel_calls` argument is specified.")
# ...

# %%
#training data
train_data=data.take(round(len(data)*.7))
train_data=train_data.batch(16)
train_data=train_data.prefetch(8)

# %%
test_data=data.skip(round(len(data)*.7))
test_data=data.take(round(len(data)*.3))
test_data=test_data.batch(16)
test_data=test_data.prefetch(8)

# %%
#embeddings

def make_embedding():
    inp=Input(shape=(100,100,3), name='input_img')
    #first block
    c1=Conv2D(64,(10,10),activation='relu',name='first')(inp)
    m1=MaxPooling2D(64,(2,2),padding='same')(c1)
    
    #second
    c2=Conv2D(128,(7,7),activation='relu')(m1)
    m2=MaxPooling2D(64,(2,2),padding='same')(c2)
              
    #third
    c3=Conv2D(128,(4,4),activation='relu')(m2)
    m3=MaxPooling2D(64,(2,2),padding='same')(c3)
              
    #fourth
    c4=Conv2D(256,(4,4),activation='relu')(m3)
    f1=Flatten()(c4)
    d1=Dense(4096,activation='sigmoid')(f1)
              
    return Model(inputs=[inp],outputs=[d1],name='embedings')

# %%
embedding=make_embedding()
embedding.summary()
# Out:
# Model: "embedings"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_img (InputLayer)      [(None, 100, 100, 3)]     0
#
#  first (Conv2D)              (None, 91, 91, 64)        19264
#
#  max_pooling2d_18 (MaxPooli  (None, 46, 46, 64)        0
#  ng2D)
#
#  conv2d_21 (Conv2D)          (None, 40, 40, 128)       401536
#
#  max_pooling2d_19 (MaxPooli  (None, 20, 20, 128)       0
#  ng2D)
#
#  conv2d_22 (Conv2D)          (None, 17, 17, 128)       262272
#
#  max_pooling2d_20 (MaxPooli  (None, 9, 9, 128)         0
#  ng2D)
#
#  conv2d_23 (Conv2D)          (None, 6, 6, 256)         524544
#
#  flatten_6 (Flatten)         (None, 9216)              0
#
#  dense_11 (Dense)            (None, 4096)              37752832
#
# ...
# Total params: 38960448 (148.62 MB)
# Trainable params: 38960448 (148.62 MB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %%
#distance layer
class L1dist(Layer):
    def __init__(self,**kwargs):
        super().__init__()
    def call(self,inputs):
        input_embedding,validation_embedding=inputs
        return tf.math.abs(input_embedding-validation_embedding)

# %%
def make_siamesemodel():
    input_image=Input(name='input_img',shape=(100,100,3))
    validation_image=Input(name='validation_img',shape=(100,100,3))
    siamese_layer=L1dist()
    siamese_layer._name='distance'
    
    distances=siamese_layer((embedding(input_image),embedding(validation_image)))
    #classifier
    classifier=Dense(1,activation='sigmoid')(distances)
    return Model(inputs=[input_image,validation_image],outputs=classifier,name='model')

# %%
make_siamesemodel().summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_img (InputLayer)      [(None, 100, 100, 3)]        0         []
#
#  validation_img (InputLayer  [(None, 100, 100, 3)]        0         []
#  )
#
#  embedings (Functional)      (None, 4096)                 3896044   ['input_img[0][0]',
#                                                           8          'validation_img[0][0]']
#
#  distance (L1dist)           (None, 4096)                 0         ['embedings[0][0]',
#                                                                      'embedings[1][0]']
#
#  dense_12 (Dense)            (None, 1)                    4097      ['distance[0][0]']
#
# ...
# Total params: 38964545 (148.64 MB)
# Trainable params: 38964545 (148.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %%
#loss and optimizer
binary_cross_loss=tf.losses.BinaryCrossentropy()

# %%
opt=tf.keras.optimizers.Adam(1e-4)

# %%
siamese_model=make_siamesemodel()

# %%
#check points
checkpoint_dir='./training_checkpoints'
checkpoint_prefix=os.path.join(checkpoint_dir,'ckpt')
checkpoint=tf.train.Checkpoint(opt=opt,siamese_model=siamese_model)

# %%
@tf.function
def train_step(batch):
    with tf.GradientTape() as tape:
        x=batch[:2]
        y=batch[2]
        #forward pass
        ypred=siamese_model(x,training=True)
        loss=binary_cross_loss(y,ypred)
    
    grad=tape.gradient(loss,siamese_model.trainable_variables)
    opt.apply_gradients(zip(grad,siamese_model.trainable_variables))
    return loss

# %%
def train(data,EPOCHS):
    for epoch in range(1,EPOCHS+1):
        print('\n Epoch{}/{}'.format(epoch,EPOCHS))
        progbar=tf.keras.utils.Progbar(len(data))
        
        for idx,batch in enumerate(data):
            train_step(batch)
            progbar.update(idx+1)
            
        if epoch%10==0 :
            checkpoint.save(file_prefix=checkpoint_prefix)

# %%
EPOCHS=30
train(train_data,EPOCHS)
# Out:
#  Epoch1/30
# 18/18 [==============================] - 47s 2s/step
#
#  Epoch2/30
# 18/18 [==============================] - 41s 2s/step
#
#  Epoch3/30
# 18/18 [==============================] - 40s 2s/step
#
#  Epoch4/30
# 18/18 [==============================] - 39s 2s/step
#
#  Epoch5/30
# 18/18 [==============================] - 40s 2s/step
#
#  Epoch6/30
# 18/18 [==============================] - 39s 2s/step
#
#  Epoch7/30
# 18/18 [==============================] - 40s 2s/step
#
#  Epoch8/30
# 18/18 [==============================] - 40s 2s/step
#
#  Epoch9/30
# 18/18 [==============================] - 44s 2s/step
#
#  Epoch10/30
# 18/18 [==============================] - 40s 2s/step
#
#  Epoch11/30
# 18/18 [==============================] - 39s 2s/step
#
#  Epoch12/30
# 18/18 [==============================] - 41s 2s/step
#
#  Epoch13/30
# 18/18 [==============================] - 41s 2s/step
#
#  Epoch14/30
# 18/18 [==============================] - 39s 2s/step
#
#  Epoch15/30
# ...

# %%
#evaluation
from tensorflow.keras.metrics import Precision,Recall

# %%
test_input,test_val,y_true=test_data.as_numpy_iterator().next()

# %%
predictions=siamese_model([test_input,test_val])
predictions
# Out:
# <tf.Tensor: shape=(16, 1), dtype=float32, numpy=
# array([[6.4871801e-07],
#        [2.6953209e-09],
#        [9.7993845e-01],
#        [4.3272209e-08],
#        [9.9988514e-01],
#        [9.9999988e-01],
#        [2.1619014e-06],
#        [1.0000000e+00],
#        [9.9946916e-01],
#        [9.8153961e-01],
#        [9.9935836e-01],
#        [9.0319567e-08],
#        [8.2171681e-08],
#        [4.7342491e-01],
#        [3.5066234e-05],
#        [2.6172424e-09]], dtype=float32)>

# %%
r=Recall()
r.update_state(y_true,predictions)
r.result().numpy()
# Out:
# 0.875

# %%
p=Precision()
p.update_state(y_true,predictions)
p.result().numpy()
# Out:
# 1.0

# %%
plt.figure(figsize=(10,8))
plt.subplot(1,2,1)
plt.imshow(test_input[0])
plt.subplot(1,2,2)
plt.imshow(test_val[0])
plt.show()

# %%
#save model
siamese_model.save('facerecg.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
#reload model
model=tf.keras.models.load_model('facerecg.h5',custom_objects={'L1dist':L1dist,'BinaryCrossentropy':tf.losses.BinaryCrossentropy})

# %%
#verification
def verify(model,detection_limit,verification_limit):
    results=[]
    for image in os.listdir(os.path.join('application_data','verification_images')):
        input_img=preprocess(os.path.join('application_data','input_images','input_image.jpg'))
        validation_img=preprocess(os.path.join('application_data','verification_images',image))
        
        result=model.predict(list(np.expand_dims([input_img,validation_img],axis=1)),verbose=0)
        results.append(result)
        
    detection=np.sum(np.array(results)>detection_limit)
    verification=detection/len(os.listdir(os.path.join('application_data','verification_images')))
    verified=verification>verification_limit
    return results,verified

# %%
cap=cv2.VideoCapture(0)
while cap.isOpened():
    ret,frame=cap.read()
    frame=frame[300:300+250,200:200+250, :]
    cv2.imshow('Image Collection',frame)
    if cv2.waitKey(10) & 0XFF==ord('v'):
        cv2.imwrite(os.path.join('application_data','input_images','input_image.jpg'),frame)
        results,verified=verify(model,0.8,0.7)
        #print(verified)
        print(verified)
    
        
    if cv2.waitKey(10) & 0XFF==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# True

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_img (InputLayer)      [(None, 100, 100, 3)]        0         []
#
#  validation_img (InputLayer  [(None, 100, 100, 3)]        0         []
#  )
#
#  embbedings (Functional)     (None, 4096)                 3896044   ['input_img[0][0]',
#                                                           8          'validation_img[0][0]']
#
#  distance (L1dist)           (None, 4096)                 0         ['embbedings[0][0]',
#                                                                      'embbedings[1][0]']
#
#  dense_10 (Dense)            (None, 1)                    4097      ['distance[0][0]']
#
# ...
# Total params: 38964545 (148.64 MB)
# Trainable params: 38964545 (148.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# ...
